# %%
from absenteeism_module import *

# %%
pd.read_csv('C:/Users/Zero/Downloads/Absenteeism_new_data.csv')
# Out:
#     ID  Reason for Absence        Date  Transportation Expense  \
# 0   22                  27  01/06/2018                     179
# 1   10                   7  04/06/2018                     361
# 2   14                  23  06/06/2018                     155
# 3   17                  25  08/06/2018                     179
# 4   14                  10  08/06/2018                     155
# 5   28                  11  11/06/2018                     225
# 6   16                   7  13/06/2018                     118
# 7   22                  27  13/06/2018                     179
# 8   34                  26  15/06/2018                     118
# 9   34                  10  20/06/2018                     118
# 10  23                  22  21/06/2018                     378
# 11  36                  19  21/06/2018                     118
# 12  12                  19  22/06/2018                     233
# 13  22                  27  22/06/2018                     179
# ...

# %%
model = absenteeism_model('model_12', 'scaler_12')

# %%
model.load_and_clean_data('C:/Users/Zero/Downloads/Absenteeism_new_data.csv')

# %%
model.predicted_output()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Transportation Expense  Age  \
# 0          0       0.0         0         1                     179   30
# 1          1       0.0         0         0                     361   28
# 2          0       0.0         0         1                     155   34
# 3          0       0.0         0         1                     179   40
# 4          1       0.0         0         0                     155   34
# 5          1       0.0         0         0                     225   28
# 6          1       0.0         0         0                     118   46
# 7          0       0.0         0         1                     179   30
# 8          0       0.0         0         1                     118   37
# 9          1       0.0         0         0                     118   37
# 10         0       0.0         0         1                     378   36
# 11         0       0.0         1         0                     118   50
# ...

# %%
model.predicted_output().to_csv('C:/Users/Zero/Downloads/Absenteeism_Predictions.csv')
